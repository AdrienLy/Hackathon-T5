# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# # Scrapping de Billboard 200

# %% [markdown]
# ![](img/BILLBOARD.png)

# %%
top_artist = pd.read_csv('top_artist_billboard_2010-2019')

# %%
top_artist.head(10)
# Out:
#            Artists  presence_in_top_per_month
# 0           Eminem                        299
# 1            Drake                        257
# 2     Taylor Swift                        218
# 3  Michael Jackson                        196
# 4   Zac Brown Band                        191
# 5    Blake Shelton                        191
# 6       Luke Bryan                        175
# 7       Bruno Mars                        165
# 8            Adele                        164
# 9      The Beatles                        148

# %% [markdown]
# # Scrapping d'Instagram

# %% [markdown]
# ![](img/instagram.png)

# %% [markdown]
# # Scrapping de twitter

# %% [markdown]
# ![](img/twitter.png)

# %% [markdown]
# # Utilisation de l'API de SPOTIFY

# %% [markdown]
# ![](img/spotify.png)

# %%
spot = pd.read_csv('X.csv')

# %%
spot.head(10)
# Out:
#    Unnamed: 0  acousticness  danceability  duration_ms  energy  \
# 0           0       0.15300         0.841       212500   0.798
# 1           1       0.12800         0.745       136032   0.715
# 2           2       0.08930         0.761       192405   0.672
# 3           3       0.01410         0.817       210368   0.539
# 4           4       0.01150         0.820       135739   0.691
# 5           5       0.29700         0.752       201661   0.488
# 6           6       0.19100         0.687       214290   0.792
# 7           7       0.07100         0.826       225199   0.615
# 8           8       0.00513         0.834       312820   0.730
# 9           9       0.55100         0.753       158053   0.498
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0          0.000003    1    0.0618    -4.206     0       0.2290   95.948
# 1          0.000000    1    0.1820    -3.368     0       0.2450   94.513
# 2          0.000010    1    0.1400    -5.887     1       0.2120  160.077
# 3          0.000496    6    0.0990    -6.349     0       0.0621   97.062
# 4          0.000000    6    0.3440    -6.646     0       0.0723  142.027
# 5          0.000009    6    0.0936    -7.050     1       0.0705  136.041
# 6          0.000000    5    0.1670    -2.749     1       0.0452  100.015
# 7          0.000000    8    0.0965    -7.979     0       0.2190   98.056
# 8          0.000000    8    0.1240    -3.714     1       0.2220  155.008
# 9          0.000000    2    0.0706    -5.610     1       0.0504   89.950
#
#    time_signature  valence  popularity
# 0               4    0.591          99
# 1               4    0.342          77
# 2               3    0.437          76
# 3               4    0.158          97
# 4               4    0.683          76
# 5               4    0.533          96
# 6               4    0.671          97
# 7               4    0.543          95
# 8               4    0.446          95
# 9               4    0.927          95

# %% [markdown]
# ## Les composantes de chansons à imposer à l'artiste :

# %% [markdown]
# ### Valance
# Positivité de la musique. Est-elle joyeuse, euphorique ou triste, dépressive etc. ?
# ### Acousticness
# Le titre est-il acoustique (proche de 1)? Ou plutôt électronique (proche de 0)?
# ### Energy
# La musique est-elle énergique ? Typiquement, a-t-elle l'air rapide, puissante et bruyante ?
# ### Key
# La clef dans laquelle la musique est jouée, (ex. en clef de Sol, Sol# etc.)
