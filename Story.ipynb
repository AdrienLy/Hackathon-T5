# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# # Scrapping de Billboard 200

# %% [markdown]
# ![](img/BILLBOARD.png)

# %%
top_artist = pd.DataFrame(columns=['artist','nbr of top per month'])
top_artist = pd.read_csv('top_artist_billboard_2010-2019',header = -1)

# %%
top_artist
# Out:
#                                                  0    1
# 0                                           Eminem  299
# 1                                            Drake  257
# 2                                     Taylor Swift  218
# 3                                  Michael Jackson  196
# 4                                   Zac Brown Band  191
# 5                                    Blake Shelton  191
# 6                                       Luke Bryan  175
# 7                                       Bruno Mars  165
# 8                                            Adele  164
# 9                                      The Beatles  148
# 10                                   Justin Bieber  128
# 11                                      Ed Sheeran  128
# 12                                  Kendrick Lamar  126
# 13                                 Imagine Dragons  123
# 14                                    Jason Aldean  121
# 15                                      The Weeknd  118
# ...
